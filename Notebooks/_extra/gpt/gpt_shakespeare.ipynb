# %%
import torch
import torch.nn as nn

import tiktoken

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,   # Vocabulary size
    "context_length": 256, # Shortened context length (orig: 1024)
    "emb_dim": 768,        # Embedding dimension
    "n_heads": 12,         # Number of attention heads
    "n_layers": 12,        # Number of layers
    "drop_rate": 0.1,      # Dropout rate
    "qkv_bias": False      # Query-key-value bias
}

# %%
# -- Attention sub-components
class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (
            1 + torch.tanh(
                torch.sqrt(torch.tensor(2.0 / torch.pi)) * 
                (x + 0.044715 * torch.pow(x, 3))
                )
        )


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]),
            GELU(),
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"])
        )

    def forward(self, x):
        return self.layers(x)


class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.emb_dim = emb_dim
        self.eps = 1e-5

        # Trainable Params that LLM adjusts during training
        # Allows model to learn appropriat scaling and shifting
        # that best suits the data processing
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift

# --- Attention mechanisms
class CausalAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, qkv_bias=False):
        super().__init__()
        self.d_out = d_out
        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)

        self.dropout = nn.Dropout(p=dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length), diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape   # (batch_size, seq_length, embedding_dim)
        keys = self.W_key(x)             # (batch_size, seq_length, d_out)
        queries = self.W_query(x)        # (batch_size, seq_length, d_out)
        values = self.W_value(x)         # (batch_size, seq_length, d_out)

        # Compute attention scores
        attn_scores = queries @ keys.transpose(1, 2)  # (batch_size, seq_length, seq_length)
        attn_scores.masked_fill_(
            self.mask.bool()[:num_tokens, :num_tokens], -torch.inf)

        # Compute attention weights with softmax
        attn_weights = torch.softmax(attn_scores / self.d_out**0.5, dim=-1)

        # Apply dropout to the attention weights
        attn_weights = self.dropout(attn_weights)

        context_vec = attn_weights @ values  # (batch_size, seq_length, d_out)
        return context_vec


class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert d_out % num_heads == 0, "d_out must be divisible by num_heads"

        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads  # Reduce proj. dim to match desired output dim

        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)

        self.out_proj = nn.Linear(d_out, d_out)  # Linear lay layer to combine heads
        self.dropout = nn.Dropout(p=dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length), diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape   # (batch_size, seq_length, embedding_dim)

        keys = self.W_key(x)             # (batch_size, seq_length, d_out)
        queries = self.W_query(x)        # (batch_size, seq_length, d_out)
        values = self.W_value(x)         # (batch_size, seq_length, d_out)

        # Implicitly split matrix by adding num_heads dimension
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose (b, num_tokens, num_heads, head_dim) to (b, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute dot product for each attention head
        attn_scores = queries @ keys.transpose(2, 3)

        # Mask truncated to number of tokens..?
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

        attn_scores.masked_fill_(mask_bool, -torch.inf)

        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        context_vec = (attn_weights @ values).transpose(1, 2)   # (b, num_tokens, num_heads, head_dim)

        # Combine heads, self.d_out = self.num_heads * self.head_dim
        context_vec = context_vec.contiguous().view(
            b, num_tokens, self.d_out
        )
        context_vec = self.out_proj(context_vec)
        return context_vec


# --- Transformer block
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.atn = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"]
        )
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.dropout_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        shortcut = x
        x = self.norm1(x)
        x = self.atn(x)
        x = self.dropout_shortcut(x)
        x = x + shortcut

        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        x = self.dropout_shortcut(x)

        return x + shortcut

# -- GPT model
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        # Transformer blocks
        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])]
        )

        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)

        pos_embeds = self.pos_emb(
            torch.arange(seq_len, device=in_idx.device)
        )

        x = tok_embeds + pos_embeds
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %%
# torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)

# %%
# -- Utilities
def generate_text_simple(model, idx, max_new_tokens, context_size):
    # idx is a (batch, n_tokens) array of indices in the current context

    for _ in range(max_new_tokens):
        # Crops current context if it exceeds the supported context size.
        # I.e if LLM supports only 5 tokens, and context size is 10,
        # then only last 5 tokens are used as context.
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)

        # Focus only on the last time step so that
        # (batch, n_token, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]

        # probas has shape (batch, vocab_size)
        # NOTE: softmax is monotonic (i.e preserves order of inputs when transformed to outputs)
        # In practice could use torch.argmax
        probas = torch.softmax(logits, dim=-1)

        # idx_next has shape (batch, 1)
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)

        # Appends sampled index to next running sequence, where idx shape (batch, n_tokens+1)
        idx = torch.cat((idx, idx_next), dim=1)

    return idx

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)
    return tokenizer.decode(flat.tolist())


start_context = "Every effort moves you"
tokenizer = tiktoken.get_encoding("gpt2")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids(start_context, tokenizer),
    max_new_tokens=10,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you.」 suggestiveNamezza":"rouch Cummings tuneose Bedford

# %% [markdown]
# #### Dataset

# %%
# -- Get the verdict training data
import os
import requests

file_path = "shakespeare.txt"
url = "https://raw.githubusercontent.com/shreydan/shakespeareGPT/refs/heads/main/data/shakespeare.txt"

if not os.path.exists(file_path):
    response = requests.get(url, timeout=30)
    response.raise_for_status()
    text_data = response.text
    with open(file_path, "w", encoding="utf-8") as file:
        file.write(text_data)
else:
    with open(file_path, "r", encoding="utf-8") as file:
        text_data = file.read()

# %%
# First 99 characters
print(text_data[:99])

# Last 99 characters
print(text_data[-99:])

total_characters = len(text_data)
total_tokens = len(tokenizer.encode(text_data))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# First Citizen:
# Before we proceed any further, hear me speak.
#
# All:
# Speak, speak.
#
# First Citizen:
# Yo
# ONIO:
# Noble Sebastian,
# Thou let'st thy fortune sleep--die, rather; wink'st
# Whiles thou art waking.
#
# Characters: 1114985
# Tokens: 337830

# %%
text_data_example = text_data[:20]

print(f"text:\n{text_data_example}")
print(tokenizer.encode(text_data[:20]))
# Out:
# text:
# First Citizen:
# Befor
# [5962, 22307, 25, 198, 33, 891, 273]

# %% [markdown]
# ##### Pytorch Dataloader

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import tiktoken


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.tokenizer = tokenizer
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

def create_dataloader_v1(txt, batch_size=4, max_length=256,
                         stride=128, shuffle=True, drop_last=True, num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset, batch_size=batch_size, shuffle=shuffle, drop_last=drop_last, num_workers=num_workers)

    return dataloader

# %%
# Train/validation ratio
train_ratio = 0.9
split_idx = int(train_ratio * len(text_data))
train_data = text_data[:split_idx]
val_data = text_data[split_idx:]

# Train/Validation loaders
torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %%
# Sanity check the context length
if total_tokens * (train_ratio) < GPT_CONFIG_124M["context_length"]:
    print("Not enough tokens for the training loader. "
          "Try to lower the `GPT_CONFIG_124M['context_length']` or "
          "increase the `training_ratio`")

if total_tokens * (1-train_ratio) < GPT_CONFIG_124M["context_length"]:
    print("Not enough tokens for the validation loader. "
          "Try to lower the `GPT_CONFIG_124M['context_length']` or "
          "decrease the `training_ratio`")

# %%
print("Train loader:")
for x, y in train_loader:
    print(x.shape, y.shape)

print("\nValidation loader:")
for x, y in val_loader:
    print(x.shape, y.shape)
# Out:
# Train loader:
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
#
# Validation loader:
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])
# torch.Size([2, 256]) torch.Size([2, 256])

# %% [markdown]
# ### Model Training

# %%
# Utility function to calculate cross entropy loss of a given batch
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch = input_batch.to(device)
    target_batch = target_batch.to(device)

    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(
        logits.flatten(0, 1), target_batch.flatten()
    )
    return loss

# Function to compute training and validation loss
def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        num_batches = min(num_batches, len(data_loader))

    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(
                input_batch, target_batch, model, device
            )
            # Sum losses for erach branch
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    # Use PyTorch 2.9 or newer for stable mps results
    major, minor = map(int, torch.__version__.split(".")[:2])
    if (major, minor) >= (2, 9):
        device = torch.device("mps")
    else:
        device = torch.device("cpu")
else:
    device = torch.device("cpu")


print(f"Using {device} device.")


model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Using cuda device.
# Training loss: 11.020919006425375
# Validation loss: 11.036462960924421

# %%
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen


def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss


def generate_and_print_sample(model, tokenizer, device, start_context, max_new_tokens=50):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=max_new_tokens, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %% [markdown]
# Training the model!

# %%
# Note:
# Uncomment the following code to calculate the execution time
# import time
# start_time = time.time()

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 10
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="First Citizen:", tokenizer=tokenizer
)

# Note:
# Uncomment the following code to show the execution time
# end_time = time.time()
# execution_time_minutes = (end_time - start_time) / 60
# print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 9.446, Val loss 9.393
# Ep 1 (Step 000005): Train loss 7.944, Val loss 7.916
# Ep 1 (Step 000010): Train loss 7.167, Val loss 6.962
# Ep 1 (Step 000015): Train loss 6.877, Val loss 6.550
# Ep 1 (Step 000020): Train loss 6.589, Val loss 6.456
# Ep 1 (Step 000025): Train loss 6.565, Val loss 6.405
# Ep 1 (Step 000030): Train loss 6.568, Val loss 6.298
# Ep 1 (Step 000035): Train loss 6.445, Val loss 6.285
# Ep 1 (Step 000040): Train loss 6.270, Val loss 6.299
# Ep 1 (Step 000045): Train loss 6.391, Val loss 6.245
# Ep 1 (Step 000050): Train loss 6.400, Val loss 6.176
# Ep 1 (Step 000055): Train loss 6.129, Val loss 6.157
# Ep 1 (Step 000060): Train loss 6.168, Val loss 6.156
# Ep 1 (Step 000065): Train loss 6.149, Val loss 6.162
# Ep 1 (Step 000070): Train loss 6.299, Val loss 6.137
# Ep 1 (Step 000075): Train loss 6.101, Val loss 6.121
# Ep 1 (Step 000080): Train loss 6.058, Val loss 6.100
# Ep 1 (Step 000085): Train loss 5.981, Val loss 6.043
# Ep 1 (Step 000090): Train loss 6.239, Val loss 6.013
# Ep 1 (Step 000095): Train loss 5.994, Val loss 5.961
# Ep 1 (Step 000100): Train loss 6.003, Val loss 5.973
# Ep 1 (Step 000105): Train loss 6.055, Val loss 5.980
# Ep 1 (Step 000110): Train loss 6.128, Val loss 5.998
# Ep 1 (Step 000115): Train loss 6.018, Val loss 5.979
# Ep 1 (Step 000120): Train loss 5.714, Val loss 5.932
# Ep 1 (Step 000125): Train loss 5.883, Val loss 5.952
# Ep 1 (Step 000130): Train loss 5.715, Val loss 5.945
# Ep 1 (Step 000135): Train loss 5.930, Val loss 5.956
# Ep 1 (Step 000140): Train loss 5.922, Val loss 5.938
# Ep 1 (Step 000145): Train loss 5.916, Val loss 5.922
# Ep 1 (Step 000150): Train loss 6.092, Val loss 5.888
# Ep 1 (Step 000155): Train loss 5.556, Val loss 5.899
# Ep 1 (Step 000160): Train loss 5.933, Val loss 5.886
# Ep 1 (Step 000165): Train loss 5.700, Val loss 5.874
# Ep 1 (Step 000170): Train loss 5.859, Val loss 5.857
# Ep 1 (Step 000175): Train loss 5.656, Val loss 5.855
# Ep 1 (Step 000180): Train loss 5.478, Val loss 5.823
# Ep 1 (Step 000185): Train loss 6.021, Val loss 5.784
# Ep 1 (Step 000190): Train loss 5.513, Val loss 5.780
# Ep 1 (Step 000195): Train loss 5.560, Val loss 5.751
# Ep 1 (Step 000200): Train loss 5.377, Val loss 5.667
# Ep 1 (Step 000205): Train loss 5.617, Val loss 5.666
# Ep 1 (Step 000210): Train loss 5.773, Val loss 5.660
# Ep 1 (Step 000215): Train loss 5.417, Val loss 5.646
# Ep 1 (Step 000220): Train loss 5.484, Val loss 5.628
# Ep 1 (Step 000225): Train loss 5.626, Val loss 5.607
# Ep 1 (Step 000230): Train loss 5.366, Val loss 5.618
# Ep 1 (Step 000235): Train loss 5.580, Val loss 5.618
# Ep 1 (Step 000240): Train loss 5.581, Val loss 5.672
# Ep 1 (Step 000245): Train loss 5.435, Val loss 5.615
# Ep 1 (Step 000250): Train loss 5.472, Val loss 5.539
# Ep 1 (Step 000255): Train loss 5.481, Val loss 5.547
# Ep 1 (Step 000260): Train loss 5.453, Val loss 5.566
# Ep 1 (Step 000265): Train loss 5.508, Val loss 5.592
# Ep 1 (Step 000270): Train loss 5.721, Val loss 5.610
# Ep 1 (Step 000275): Train loss 5.298, Val loss 5.594
# Ep 1 (Step 000280): Train loss 5.431, Val loss 5.591
# Ep 1 (Step 000285): Train loss 5.311, Val loss 5.613
# Ep 1 (Step 000290): Train loss 5.364, Val loss 5.574
# Ep 1 (Step 000295): Train loss 5.219, Val loss 5.565
# Ep 1 (Step 000300): Train loss 5.511, Val loss 5.586
# Ep 1 (Step 000305): Train loss 5.404, Val loss 5.542
# Ep 1 (Step 000310): Train loss 5.438, Val loss 5.546
# Ep 1 (Step 000315): Train loss 5.198, Val loss 5.512
# Ep 1 (Step 000320): Train loss 5.520, Val loss 5.540
# Ep 1 (Step 000325): Train loss 5.018, Val loss 5.499
# Ep 1 (Step 000330): Train loss 5.439, Val loss 5.509
# Ep 1 (Step 000335): Train loss 5.322, Val loss 5.514
# Ep 1 (Step 000340): Train loss 5.268, Val loss 5.535
# Ep 1 (Step 000345): Train loss 5.217, Val loss 5.552
# Ep 1 (Step 000350): Train loss 5.582, Val loss 5.478
# Ep 1 (Step 000355): Train loss 5.119, Val loss 5.471
# Ep 1 (Step 000360): Train loss 5.391, Val loss 5.476
# Ep 1 (Step 000365): Train loss 4.945, Val loss 5.429
# Ep 1 (Step 000370): Train loss 5.003, Val loss 5.363
# Ep 1 (Step 000375): Train loss 5.391, Val loss 5.407
# Ep 1 (Step 000380): Train loss 5.339, Val loss 5.361
# Ep 1 (Step 000385): Train loss 5.528, Val loss 5.398
# Ep 1 (Step 000390): Train loss 5.266, Val loss 5.397
# Ep 1 (Step 000395): Train loss 5.065, Val loss 5.379
# Ep 1 (Step 000400): Train loss 5.339, Val loss 5.332
# Ep 1 (Step 000405): Train loss 5.321, Val loss 5.250
# Ep 1 (Step 000410): Train loss 5.114, Val loss 5.203
# Ep 1 (Step 000415): Train loss 5.244, Val loss 5.225
# Ep 1 (Step 000420): Train loss 4.845, Val loss 5.227
# Ep 1 (Step 000425): Train loss 4.968, Val loss 5.273
# Ep 1 (Step 000430): Train loss 5.176, Val loss 5.286
# Ep 1 (Step 000435): Train loss 5.177, Val loss 5.288
# Ep 1 (Step 000440): Train loss 5.036, Val loss 5.282
# Ep 1 (Step 000445): Train loss 4.913, Val loss 5.301
# Ep 1 (Step 000450): Train loss 5.164, Val loss 5.345
# Ep 1 (Step 000455): Train loss 4.967, Val loss 5.303
# Ep 1 (Step 000460): Train loss 4.941, Val loss 5.298
# Ep 1 (Step 000465): Train loss 5.011, Val loss 5.288
# Ep 1 (Step 000470): Train loss 4.952, Val loss 5.231
# Ep 1 (Step 000475): Train loss 5.026, Val loss 5.281
# Ep 1 (Step 000480): Train loss 4.944, Val loss 5.274
# Ep 1 (Step 000485): Train loss 4.865, Val loss 5.282
# Ep 1 (Step 000490): Train loss 5.216, Val loss 5.298
# Ep 1 (Step 000495): Train loss 4.787, Val loss 5.278
# Ep 1 (Step 000500): Train loss 4.742, Val loss 5.317
# Ep 1 (Step 000505): Train loss 4.886, Val loss 5.298
# Ep 1 (Step 000510): Train loss 5.083, Val loss 5.294
# Ep 1 (Step 000515): Train loss 4.578, Val loss 5.294
# Ep 1 (Step 000520): Train loss 4.626, Val loss 5.286
# Ep 1 (Step 000525): Train loss 4.744, Val loss 5.289
# Ep 1 (Step 000530): Train loss 5.092, Val loss 5.275
# Ep 1 (Step 000535): Train loss 4.888, Val loss 5.250
# Ep 1 (Step 000540): Train loss 5.164, Val loss 5.235
# Ep 1 (Step 000545): Train loss 4.737, Val loss 5.197
# Ep 1 (Step 000550): Train loss 5.014, Val loss 5.227
# Ep 1 (Step 000555): Train loss 5.015, Val loss 5.246
# Ep 1 (Step 000560): Train loss 4.839, Val loss 5.215
# Ep 1 (Step 000565): Train loss 4.723, Val loss 5.249
# Ep 1 (Step 000570): Train loss 5.019, Val loss 5.292
# Ep 1 (Step 000575): Train loss 5.023, Val loss 5.307
# Ep 1 (Step 000580): Train loss 4.745, Val loss 5.284
# Ep 1 (Step 000585): Train loss 5.104, Val loss 5.281
# First Citizen:
# Ep 2 (Step 000590): Train loss 4.805, Val loss 5.264
# Ep 2 (Step 000595): Train loss 4.741, Val loss 5.275
# Ep 2 (Step 000600): Train loss 4.695, Val loss 5.303
# Ep 2 (Step 000605): Train loss 5.074, Val loss 5.290
# Ep 2 (Step 000610): Train loss 4.822, Val loss 5.263
# Ep 2 (Step 000615): Train loss 4.485, Val loss 5.225
# Ep 2 (Step 000620): Train loss 4.500, Val loss 5.201
# Ep 2 (Step 000625): Train loss 4.497, Val loss 5.198
# Ep 4 (Step 002075): Train loss 3.826, Val loss 4.551
# Ep 4 (Step 002080): Train loss 3.972, Val loss 4.565
# Ep 4 (Step 002085): Train loss 4.123, Val loss 4.578
# Ep 4 (Step 002090): Train loss 3.931, Val loss 4.594
# Ep 4 (Step 002095): Train loss 3.809, Val loss 4.597
# Ep 4 (Step 002100): Train loss 4.000, Val loss 4.605
# Ep 4 (Step 002105): Train loss 3.867, Val loss 4.609
# Ep 4 (Step 002110): Train loss 3.778, Val loss 4.655
# Ep 4 (Step 002115): Train loss 3.937, Val loss 4.649
# Ep 4 (Step 002120): Train loss 3.884, Val loss 4.641
# Ep 4 (Step 002125): Train loss 3.644, Val loss 4.623
# Ep 4 (Step 002130): Train loss 3.830, Val loss 4.616
# Ep 4 (Step 002135): Train loss 3.962, Val loss 4.610
# Ep 4 (Step 002140): Train loss 3.868, Val loss 4.586
# Ep 4 (Step 002145): Train loss 3.919, Val loss 4.568
# Ep 4 (Step 002150): Train loss 3.651, Val loss 4.587
# Ep 4 (Step 002155): Train loss 3.825, Val loss 4.593
# Ep 4 (Step 002160): Train loss 3.471, Val loss 4.602
# Ep 4 (Step 002165): Train loss 3.874, Val loss 4.592
# Ep 4 (Step 002170): Train loss 3.602, Val loss 4.589
# Ep 4 (Step 002175): Train loss 3.766, Val loss 4.623
# Ep 4 (Step 002180): Train loss 3.467, Val loss 4.618
# Ep 4 (Step 002185): Train loss 3.638, Val loss 4.600
# Ep 4 (Step 002190): Train loss 4.043, Val loss 4.561
# Ep 4 (Step 002195): Train loss 3.731, Val loss 4.579
# Ep 4 (Step 002200): Train loss 3.641, Val loss 4.593
# Ep 4 (Step 002205): Train loss 3.951, Val loss 4.595
# Ep 4 (Step 002210): Train loss 3.647, Val loss 4.568
# Ep 4 (Step 002215): Train loss 3.804, Val loss 4.569
# Ep 4 (Step 002220): Train loss 3.717, Val loss 4.587
# Ep 4 (Step 002225): Train loss 3.546, Val loss 4.586
# Ep 4 (Step 002230): Train loss 3.420, Val loss 4.577
# Ep 4 (Step 002235): Train loss 3.501, Val loss 4.601
# Ep 4 (Step 002240): Train loss 3.659, Val loss 4.627
# Ep 4 (Step 002245): Train loss 3.598, Val loss 4.616
# Ep 4 (Step 002250): Train loss 3.754, Val loss 4.592
# Ep 4 (Step 002255): Train loss 3.795, Val loss 4.570
# Ep 4 (Step 002260): Train loss 3.638, Val loss 4.564
# Ep 4 (Step 002265): Train loss 3.736, Val loss 4.575
# Ep 4 (Step 002270): Train loss 3.732, Val loss 4.597
# Ep 4 (Step 002275): Train loss 3.788, Val loss 4.612
# Ep 4 (Step 002280): Train loss 3.457, Val loss 4.581
# Ep 4 (Step 002285): Train loss 3.641, Val loss 4.545
# Ep 4 (Step 002290): Train loss 4.036, Val loss 4.507
# Ep 4 (Step 002295): Train loss 3.740, Val loss 4.509
# Ep 4 (Step 002300): Train loss 3.616, Val loss 4.509
# Ep 4 (Step 002305): Train loss 3.697, Val loss 4.503
# Ep 4 (Step 002310): Train loss 3.622, Val loss 4.497
# Ep 4 (Step 002315): Train loss 3.712, Val loss 4.524
# Ep 4 (Step 002320): Train loss 3.752, Val loss 4.553
# Ep 4 (Step 002325): Train loss 3.691, Val loss 4.554
# Ep 4 (Step 002330): Train loss 3.800, Val loss 4.541
# Ep 4 (Step 002335): Train loss 3.499, Val loss 4.540
# Ep 4 (Step 002340): Train loss 3.547, Val loss 4.534
# Ep 4 (Step 002345): Train loss 3.680, Val loss 4.533
# Ep 4 (Step 002350): Train loss 3.526, Val loss 4.536
# Ep 4 (Step 002355): Train loss 3.381, Val loss 4.552
# First Citizen: I would you are to the people, And that we have you And that we have you, And you have been And so, And so, And so, And so, And, And so,
# Ep 5 (Step 002360): Train loss 3.567, Val loss 4.568
# Ep 5 (Step 002365): Train loss 3.784, Val loss 4.590
# Ep 5 (Step 002370): Train loss 3.610, Val loss 4.587
# Ep 5 (Step 002375): Train loss 3.677, Val loss 4.609
# Ep 5 (Step 002380): Train loss 3.640, Val loss 4.566
# Ep 5 (Step 002385): Train loss 3.420, Val loss 4.567
# Ep 5 (Step 002390): Train loss 3.339, Val loss 4.527
# Ep 5 (Step 002395): Train loss 3.642, Val loss 4.538
# Ep 5 (Step 002400): Train loss 3.400, Val loss 4.561
# Ep 5 (Step 002405): Train loss 3.696, Val loss 4.547
# Ep 5 (Step 002410): Train loss 3.730, Val loss 4.527
# Ep 5 (Step 002415): Train loss 3.646, Val loss 4.538
# Ep 5 (Step 002420): Train loss 3.635, Val loss 4.553
# Ep 5 (Step 002425): Train loss 3.749, Val loss 4.528
# Ep 5 (Step 002430): Train loss 3.710, Val loss 4.501
# Ep 5 (Step 002435): Train loss 3.740, Val loss 4.505
# Ep 5 (Step 002440): Train loss 3.354, Val loss 4.501
# Ep 5 (Step 002445): Train loss 3.677, Val loss 4.490
# Ep 5 (Step 002450): Train loss 3.502, Val loss 4.507
# Ep 5 (Step 002455): Train loss 3.700, Val loss 4.505
# Ep 5 (Step 002460): Train loss 3.669, Val loss 4.501
# Ep 5 (Step 002465): Train loss 3.726, Val loss 4.500
# Ep 5 (Step 002470): Train loss 3.822, Val loss 4.508
# Ep 5 (Step 002475): Train loss 3.400, Val loss 4.501
# Ep 5 (Step 002480): Train loss 3.223, Val loss 4.525
# Ep 5 (Step 002485): Train loss 3.434, Val loss 4.532
# Ep 5 (Step 002490): Train loss 3.195, Val loss 4.533
# Ep 5 (Step 002495): Train loss 3.492, Val loss 4.553
# Ep 5 (Step 002500): Train loss 3.785, Val loss 4.519
# Ep 5 (Step 002505): Train loss 3.849, Val loss 4.531
# Ep 5 (Step 002510): Train loss 3.883, Val loss 4.540
# Ep 5 (Step 002515): Train loss 3.710, Val loss 4.551
# Ep 5 (Step 002520): Train loss 3.659, Val loss 4.531
# Ep 5 (Step 002525): Train loss 3.634, Val loss 4.532
# Ep 5 (Step 002530): Train loss 3.603, Val loss 4.541
# Ep 5 (Step 002535): Train loss 3.514, Val loss 4.540
# Ep 5 (Step 002540): Train loss 3.347, Val loss 4.578
# Ep 5 (Step 002545): Train loss 3.533, Val loss 4.572
# Ep 5 (Step 002550): Train loss 3.848, Val loss 4.579
# Ep 5 (Step 002555): Train loss 3.249, Val loss 4.561
# Ep 5 (Step 002560): Train loss 3.747, Val loss 4.558
# Ep 5 (Step 002565): Train loss 3.387, Val loss 4.551
# Ep 5 (Step 002570): Train loss 3.573, Val loss 4.573
# Ep 5 (Step 002575): Train loss 3.371, Val loss 4.562
# Ep 5 (Step 002580): Train loss 3.399, Val loss 4.532
# Ep 5 (Step 002585): Train loss 3.457, Val loss 4.519
# Ep 5 (Step 002590): Train loss 3.781, Val loss 4.515
# Ep 5 (Step 002595): Train loss 3.395, Val loss 4.501
# Ep 5 (Step 002600): Train loss 3.729, Val loss 4.523
# Ep 5 (Step 002605): Train loss 3.594, Val loss 4.523
# Ep 5 (Step 002610): Train loss 3.936, Val loss 4.501
# Ep 5 (Step 002615): Train loss 3.692, Val loss 4.519
# Ep 5 (Step 002620): Train loss 3.478, Val loss 4.523
# Ep 5 (Step 002625): Train loss 3.541, Val loss 4.505
# Ep 5 (Step 002630): Train loss 3.360, Val loss 4.502
# Ep 5 (Step 002635): Train loss 3.628, Val loss 4.484
# Ep 5 (Step 002640): Train loss 3.317, Val loss 4.498
# Ep 5 (Step 002645): Train loss 3.627, Val loss 4.529
# Ep 5 (Step 002650): Train loss 3.478, Val loss 4.534
# Ep 5 (Step 002655): Train loss 3.600, Val loss 4.524
# Ep 5 (Step 002660): Train loss 3.738, Val loss 4.519
# Ep 5 (Step 002665): Train loss 3.620, Val loss 4.555
# Ep 5 (Step 002670): Train loss 3.460, Val loss 4.565
# Ep 5 (Step 002675): Train loss 3.256, Val loss 4.562
# Ep 5 (Step 002680): Train loss 3.344, Val loss 4.553
# Ep 5 (Step 002685): Train loss 3.628, Val loss 4.554
# Ep 5 (Step 002690): Train loss 3.582, Val loss 4.583
# Ep 5 (Step 002695): Train loss 3.456, Val loss 4.592
# Ep 5 (Step 002700): Train loss 3.673, Val loss 4.571
# Ep 5 (Step 002705): Train loss 3.364, Val loss 4.562
# Ep 5 (Step 002710): Train loss 3.383, Val loss 4.574
# Ep 5 (Step 002715): Train loss 3.254, Val loss 4.566
# Ep 5 (Step 002720): Train loss 3.210, Val loss 4.575
# Ep 5 (Step 002725): Train loss 3.438, Val loss 4.559
# Ep 5 (Step 002730): Train loss 3.248, Val loss 4.539
# Ep 5 (Step 002735): Train loss 3.494, Val loss 4.547
# Ep 5 (Step 002740): Train loss 3.393, Val loss 4.554
# Ep 5 (Step 002745): Train loss 3.626, Val loss 4.553
# Ep 5 (Step 002750): Train loss 3.718, Val loss 4.534
# Ep 5 (Step 002755): Train loss 3.547, Val loss 4.525
# Ep 5 (Step 002760): Train loss 3.598, Val loss 4.510
# Ep 5 (Step 002765): Train loss 3.747, Val loss 4.518
# Ep 5 (Step 002770): Train loss 3.253, Val loss 4.500
# Ep 5 (Step 002775): Train loss 3.433, Val loss 4.485
# Ep 5 (Step 002780): Train loss 3.544, Val loss 4.502
# Ep 5 (Step 002785): Train loss 3.447, Val loss 4.494
# Ep 5 (Step 002790): Train loss 3.350, Val loss 4.514
# Ep 5 (Step 002795): Train loss 3.731, Val loss 4.491
# Ep 5 (Step 002800): Train loss 3.451, Val loss 4.480
# Ep 5 (Step 002805): Train loss 3.569, Val loss 4.473
# Ep 5 (Step 002810): Train loss 3.094, Val loss 4.509
# Ep 5 (Step 002815): Train loss 3.253, Val loss 4.513
# Ep 5 (Step 002820): Train loss 3.261, Val loss 4.519
# Ep 5 (Step 002825): Train loss 3.562, Val loss 4.556
# Ep 5 (Step 002830): Train loss 3.556, Val loss 4.565
# Ep 5 (Step 002835): Train loss 3.177, Val loss 4.578
# Ep 5 (Step 002840): Train loss 3.322, Val loss 4.584
# Ep 5 (Step 002845): Train loss 3.265, Val loss 4.547
# Ep 5 (Step 002850): Train loss 3.395, Val loss 4.548
# Ep 5 (Step 002855): Train loss 3.552, Val loss 4.544
# Ep 5 (Step 002860): Train loss 3.388, Val loss 4.567
# Ep 5 (Step 002865): Train loss 3.429, Val loss 4.571
# Ep 5 (Step 002870): Train loss 3.146, Val loss 4.564
# Ep 5 (Step 002875): Train loss 3.453, Val loss 4.542
# Ep 5 (Step 002880): Train loss 3.479, Val loss 4.556
# Ep 5 (Step 002885): Train loss 3.379, Val loss 4.551
# Ep 5 (Step 002890): Train loss 3.106, Val loss 4.534
# Ep 5 (Step 002895): Train loss 3.235, Val loss 4.524
# Ep 5 (Step 002900): Train loss 3.473, Val loss 4.520
# Ep 5 (Step 002905): Train loss 3.511, Val loss 4.543
# Ep 5 (Step 002910): Train loss 3.576, Val loss 4.540
# Ep 5 (Step 002915): Train loss 3.348, Val loss 4.541
# Ep 5 (Step 002920): Train loss 3.442, Val loss 4.532
# Ep 5 (Step 002925): Train loss 3.234, Val loss 4.540
# Ep 5 (Step 002930): Train loss 3.216, Val loss 4.489
# Ep 5 (Step 002935): Train loss 3.473, Val loss 4.474
# Ep 5 (Step 002940): Train loss 3.353, Val loss 4.462
# First Citizen: I have not so but you, sir, sir, sir, sir, sir, sir, sir, sir, I am not a him him, sir, I have been but you, sir, And I have been
# Ep 6 (Step 002945): Train loss 3.574, Val loss 4.473
# Ep 6 (Step 002950): Train loss 3.365, Val loss 4.477
# Ep 6 (Step 002955): Train loss 3.364, Val loss 4.496
# Ep 6 (Step 002960): Train loss 3.456, Val loss 4.483
# Ep 6 (Step 002965): Train loss 3.209, Val loss 4.506
# Ep 6 (Step 002970): Train loss 3.388, Val loss 4.541
# Ep 6 (Step 002975): Train loss 3.141, Val loss 4.542
# Ep 6 (Step 002980): Train loss 3.453, Val loss 4.520
# Ep 6 (Step 002985): Train loss 3.169, Val loss 4.519
# Ep 6 (Step 002990): Train loss 3.215, Val loss 4.545
# Ep 6 (Step 002995): Train loss 3.290, Val loss 4.536
# Ep 6 (Step 003000): Train loss 3.136, Val loss 4.533
# Ep 6 (Step 003005): Train loss 3.247, Val loss 4.538
# Ep 6 (Step 003010): Train loss 3.226, Val loss 4.544
# Ep 6 (Step 003015): Train loss 3.378, Val loss 4.561
# Ep 6 (Step 003020): Train loss 3.332, Val loss 4.579
# Ep 6 (Step 003025): Train loss 3.091, Val loss 4.600
# Ep 6 (Step 003030): Train loss 3.314, Val loss 4.587
# Ep 6 (Step 003035): Train loss 3.079, Val loss 4.612
# Ep 6 (Step 003040): Train loss 3.266, Val loss 4.612
# Ep 6 (Step 003045): Train loss 3.128, Val loss 4.577
# Ep 6 (Step 003050): Train loss 3.263, Val loss 4.597
# Ep 6 (Step 003055): Train loss 3.148, Val loss 4.582
# Ep 6 (Step 003060): Train loss 3.178, Val loss 4.579
# Ep 6 (Step 003065): Train loss 2.977, Val loss 4.597
# Ep 6 (Step 003070): Train loss 3.268, Val loss 4.566
# Ep 6 (Step 003075): Train loss 3.133, Val loss 4.551
# Ep 6 (Step 003080): Train loss 3.173, Val loss 4.538
# Ep 6 (Step 003085): Train loss 3.176, Val loss 4.552
# Ep 6 (Step 003090): Train loss 3.182, Val loss 4.541
# Ep 6 (Step 003095): Train loss 3.364, Val loss 4.529
# Ep 6 (Step 003100): Train loss 3.324, Val loss 4.540
# Ep 6 (Step 003105): Train loss 3.428, Val loss 4.583
# Ep 6 (Step 003110): Train loss 3.458, Val loss 4.576
# Ep 6 (Step 003115): Train loss 3.437, Val loss 4.555
# Ep 6 (Step 003120): Train loss 3.154, Val loss 4.555
# Ep 6 (Step 003125): Train loss 3.117, Val loss 4.566
# Ep 6 (Step 003130): Train loss 3.140, Val loss 4.545
# Ep 6 (Step 003135): Train loss 3.221, Val loss 4.556
# Ep 6 (Step 003140): Train loss 3.099, Val loss 4.593
# Ep 6 (Step 003145): Train loss 3.136, Val loss 4.605
# Ep 6 (Step 003150): Train loss 3.123, Val loss 4.611
# Ep 6 (Step 003155): Train loss 3.208, Val loss 4.627
# Ep 6 (Step 003160): Train loss 3.440, Val loss 4.603
# Ep 6 (Step 003165): Train loss 3.239, Val loss 4.592
# Ep 6 (Step 003170): Train loss 3.200, Val loss 4.603
# Ep 6 (Step 003175): Train loss 3.057, Val loss 4.604
# Ep 6 (Step 003180): Train loss 3.297, Val loss 4.610
# Ep 6 (Step 003185): Train loss 3.165, Val loss 4.609
# Ep 6 (Step 003190): Train loss 3.278, Val loss 4.623
# Ep 6 (Step 003195): Train loss 2.963, Val loss 4.648
# Ep 6 (Step 003200): Train loss 3.307, Val loss 4.654
# Ep 6 (Step 003205): Train loss 3.019, Val loss 4.670
# Ep 6 (Step 003210): Train loss 3.624, Val loss 4.651
# Ep 6 (Step 003215): Train loss 3.363, Val loss 4.633
# Ep 6 (Step 003220): Train loss 3.435, Val loss 4.648
# Ep 6 (Step 003225): Train loss 3.109, Val loss 4.640
# Ep 6 (Step 003230): Train loss 3.253, Val loss 4.608
# Ep 6 (Step 003235): Train loss 3.301, Val loss 4.605
# Ep 6 (Step 003240): Train loss 3.472, Val loss 4.585
# Ep 6 (Step 003245): Train loss 3.104, Val loss 4.569
# Ep 6 (Step 003250): Train loss 3.663, Val loss 4.562
# Ep 6 (Step 003255): Train loss 3.328, Val loss 4.574
# Ep 6 (Step 003260): Train loss 3.408, Val loss 4.566
# Ep 6 (Step 003265): Train loss 3.218, Val loss 4.573
# Ep 6 (Step 003270): Train loss 2.923, Val loss 4.571
# Ep 6 (Step 003275): Train loss 3.358, Val loss 4.585
# Ep 6 (Step 003280): Train loss 3.206, Val loss 4.587
# Ep 6 (Step 003285): Train loss 3.146, Val loss 4.610
# Ep 6 (Step 003290): Train loss 3.340, Val loss 4.630
# Ep 6 (Step 003295): Train loss 3.188, Val loss 4.625
# Ep 6 (Step 003300): Train loss 3.026, Val loss 4.599
# Ep 6 (Step 003305): Train loss 3.193, Val loss 4.575
# Ep 6 (Step 003310): Train loss 3.372, Val loss 4.598
# Ep 6 (Step 003315): Train loss 3.069, Val loss 4.624
# Ep 6 (Step 003320): Train loss 3.108, Val loss 4.606
# Ep 6 (Step 003325): Train loss 3.252, Val loss 4.587
# Ep 6 (Step 003330): Train loss 2.963, Val loss 4.579
# Ep 6 (Step 003335): Train loss 3.161, Val loss 4.534
# Ep 6 (Step 003340): Train loss 3.271, Val loss 4.510
# Ep 6 (Step 003345): Train loss 3.205, Val loss 4.502
# Ep 6 (Step 003350): Train loss 3.345, Val loss 4.493
# Ep 6 (Step 003355): Train loss 3.206, Val loss 4.490
# Ep 6 (Step 003360): Train loss 2.977, Val loss 4.503
# Ep 6 (Step 003365): Train loss 3.067, Val loss 4.512
# Ep 6 (Step 003370): Train loss 3.073, Val loss 4.510
# Ep 6 (Step 003375): Train loss 2.864, Val loss 4.505
# Ep 6 (Step 003380): Train loss 2.818, Val loss 4.479
# Ep 6 (Step 003385): Train loss 3.068, Val loss 4.478
# Ep 6 (Step 003390): Train loss 3.137, Val loss 4.488
# Ep 6 (Step 003395): Train loss 3.286, Val loss 4.510
# Ep 6 (Step 003400): Train loss 3.117, Val loss 4.511
# Ep 6 (Step 003405): Train loss 3.295, Val loss 4.515
# Ep 6 (Step 003410): Train loss 3.127, Val loss 4.526
# Ep 6 (Step 003415): Train loss 3.192, Val loss 4.527
# Ep 6 (Step 003420): Train loss 2.936, Val loss 4.494
# Ep 6 (Step 003425): Train loss 3.140, Val loss 4.459
# Ep 6 (Step 003430): Train loss 3.019, Val loss 4.467
# Ep 6 (Step 003435): Train loss 3.110, Val loss 4.480
# Ep 6 (Step 003440): Train loss 2.953, Val loss 4.457
# Ep 6 (Step 003445): Train loss 3.171, Val loss 4.463
# Ep 6 (Step 003450): Train loss 2.975, Val loss 4.464
# Ep 6 (Step 003455): Train loss 2.905, Val loss 4.484
# Ep 6 (Step 003460): Train loss 2.963, Val loss 4.489
# Ep 6 (Step 003465): Train loss 3.103, Val loss 4.517
# Ep 6 (Step 003470): Train loss 2.842, Val loss 4.525
# Ep 6 (Step 003475): Train loss 3.141, Val loss 4.515
# Ep 6 (Step 003480): Train loss 2.935, Val loss 4.519
# Ep 6 (Step 003485): Train loss 3.070, Val loss 4.519
# Ep 6 (Step 003490): Train loss 3.167, Val loss 4.516
# Ep 6 (Step 003495): Train loss 3.102, Val loss 4.528
# Ep 6 (Step 003500): Train loss 3.049, Val loss 4.520
# Ep 6 (Step 003505): Train loss 2.972, Val loss 4.522
# Ep 6 (Step 003510): Train loss 2.950, Val loss 4.539
# Ep 6 (Step 003515): Train loss 2.928, Val loss 4.519
# Ep 6 (Step 003520): Train loss 3.156, Val loss 4.488
# Ep 6 (Step 003525): Train loss 3.223, Val loss 4.488
# Ep 6 (Step 003530): Train loss 3.061, Val loss 4.504
# First Citizen: I have no other, I have been To have been Third Gentleman: I have no man, I have no more the inside of the king: he had the the sea the inside and Third Gentleman:
# Ep 7 (Step 003535): Train loss 2.905, Val loss 4.484
# Ep 7 (Step 003540): Train loss 3.087, Val loss 4.476
# Ep 7 (Step 003545): Train loss 2.977, Val loss 4.501
# Ep 7 (Step 003550): Train loss 2.738, Val loss 4.505
# Ep 7 (Step 003555): Train loss 3.063, Val loss 4.516
# Ep 7 (Step 003560): Train loss 2.780, Val loss 4.514
# Ep 7 (Step 003565): Train loss 2.987, Val loss 4.516
# Ep 7 (Step 003570): Train loss 2.934, Val loss 4.538
# Ep 7 (Step 003575): Train loss 2.979, Val loss 4.554
# Ep 7 (Step 003580): Train loss 2.983, Val loss 4.560
# Ep 7 (Step 003585): Train loss 2.835, Val loss 4.580
# Ep 7 (Step 003590): Train loss 3.030, Val loss 4.611
# Ep 7 (Step 003595): Train loss 2.802, Val loss 4.620
# Ep 7 (Step 003600): Train loss 2.703, Val loss 4.623
# Ep 7 (Step 003605): Train loss 2.971, Val loss 4.637
# Ep 7 (Step 003610): Train loss 2.958, Val loss 4.644
# Ep 7 (Step 003615): Train loss 2.896, Val loss 4.650
# Ep 7 (Step 003620): Train loss 2.726, Val loss 4.622
# Ep 7 (Step 003625): Train loss 2.824, Val loss 4.628
# Ep 7 (Step 003630): Train loss 2.983, Val loss 4.650
# Ep 7 (Step 003635): Train loss 2.881, Val loss 4.648
# Ep 7 (Step 003640): Train loss 2.806, Val loss 4.635
# Ep 7 (Step 003645): Train loss 2.914, Val loss 4.632
# Ep 7 (Step 003650): Train loss 3.176, Val loss 4.591
# Ep 7 (Step 003655): Train loss 3.029, Val loss 4.587
# Ep 7 (Step 003660): Train loss 3.004, Val loss 4.591
# Ep 7 (Step 003665): Train loss 3.120, Val loss 4.574
# Ep 7 (Step 003670): Train loss 3.154, Val loss 4.568
# Ep 7 (Step 003675): Train loss 2.571, Val loss 4.548
# Ep 7 (Step 003680): Train loss 2.846, Val loss 4.537
# Ep 7 (Step 003685): Train loss 2.858, Val loss 4.538
# Ep 7 (Step 003690): Train loss 3.044, Val loss 4.550
# Ep 7 (Step 003695): Train loss 2.690, Val loss 4.573
# Ep 7 (Step 003700): Train loss 2.860, Val loss 4.604
# Ep 7 (Step 003705): Train loss 2.994, Val loss 4.597
# Ep 7 (Step 003710): Train loss 3.015, Val loss 4.612
# Ep 7 (Step 003715): Train loss 3.125, Val loss 4.604
# Ep 7 (Step 003720): Train loss 2.974, Val loss 4.621
# Ep 7 (Step 003725): Train loss 2.809, Val loss 4.616
# Ep 7 (Step 003730): Train loss 2.693, Val loss 4.600
# Ep 7 (Step 003735): Train loss 2.653, Val loss 4.600
# Ep 7 (Step 003740): Train loss 2.833, Val loss 4.626
# Ep 7 (Step 003745): Train loss 2.589, Val loss 4.603
# Ep 7 (Step 003750): Train loss 2.976, Val loss 4.605
# Ep 7 (Step 003755): Train loss 2.813, Val loss 4.618
# Ep 7 (Step 003760): Train loss 2.877, Val loss 4.605
# Ep 7 (Step 003765): Train loss 2.727, Val loss 4.603
# Ep 7 (Step 003770): Train loss 2.830, Val loss 4.621
# Ep 7 (Step 003775): Train loss 2.988, Val loss 4.603
# Ep 7 (Step 003780): Train loss 2.960, Val loss 4.623
# Ep 7 (Step 003785): Train loss 2.608, Val loss 4.655
# Ep 7 (Step 003790): Train loss 2.614, Val loss 4.641
# Ep 7 (Step 003795): Train loss 2.804, Val loss 4.617
# Ep 7 (Step 003800): Train loss 2.799, Val loss 4.606
# Ep 7 (Step 003805): Train loss 2.827, Val loss 4.617
# Ep 7 (Step 003810): Train loss 3.006, Val loss 4.621
# Ep 7 (Step 003815): Train loss 2.963, Val loss 4.626
# Ep 7 (Step 003820): Train loss 2.848, Val loss 4.658
# Ep 7 (Step 003825): Train loss 3.080, Val loss 4.651
# Ep 7 (Step 003830): Train loss 2.848, Val loss 4.640
# Ep 7 (Step 003835): Train loss 2.914, Val loss 4.647
# Ep 7 (Step 003840): Train loss 2.710, Val loss 4.643
# Ep 7 (Step 003845): Train loss 2.877, Val loss 4.634
# Ep 7 (Step 003850): Train loss 2.829, Val loss 4.647
# Ep 7 (Step 003855): Train loss 2.824, Val loss 4.621
# Ep 7 (Step 003860): Train loss 2.791, Val loss 4.631
# Ep 7 (Step 003865): Train loss 3.131, Val loss 4.638
# Ep 7 (Step 003870): Train loss 2.718, Val loss 4.602
# Ep 7 (Step 003875): Train loss 2.763, Val loss 4.578
# Ep 7 (Step 003880): Train loss 2.873, Val loss 4.589
# Ep 7 (Step 003885): Train loss 2.483, Val loss 4.601
# Ep 7 (Step 003890): Train loss 2.696, Val loss 4.619
# Ep 7 (Step 003895): Train loss 2.475, Val loss 4.600
# Ep 7 (Step 003900): Train loss 2.657, Val loss 4.581
# Ep 7 (Step 003905): Train loss 2.750, Val loss 4.572
# Ep 7 (Step 003910): Train loss 2.665, Val loss 4.582
# Ep 7 (Step 003915): Train loss 2.851, Val loss 4.609
# Ep 7 (Step 003920): Train loss 2.743, Val loss 4.571
# Ep 7 (Step 003925): Train loss 2.576, Val loss 4.581
# Ep 7 (Step 003930): Train loss 2.807, Val loss 4.593
# Ep 7 (Step 003935): Train loss 2.830, Val loss 4.597
# Ep 7 (Step 003940): Train loss 2.780, Val loss 4.603
# Ep 7 (Step 003945): Train loss 2.687, Val loss 4.616
# Ep 7 (Step 003950): Train loss 2.717, Val loss 4.613
# Ep 7 (Step 003955): Train loss 2.836, Val loss 4.579
# Ep 7 (Step 003960): Train loss 2.673, Val loss 4.584
# Ep 7 (Step 003965): Train loss 2.559, Val loss 4.592
# Ep 7 (Step 003970): Train loss 2.671, Val loss 4.605
# Ep 7 (Step 003975): Train loss 2.827, Val loss 4.618
# Ep 7 (Step 003980): Train loss 2.621, Val loss 4.627
# Ep 7 (Step 003985): Train loss 2.763, Val loss 4.628
# Ep 7 (Step 003990): Train loss 2.536, Val loss 4.632
# Ep 7 (Step 003995): Train loss 2.463, Val loss 4.613
# Ep 7 (Step 004000): Train loss 2.637, Val loss 4.601
# Ep 7 (Step 004005): Train loss 2.715, Val loss 4.607
# Ep 7 (Step 004010): Train loss 2.736, Val loss 4.628
# Ep 7 (Step 004015): Train loss 2.907, Val loss 4.624
# Ep 7 (Step 004020): Train loss 2.575, Val loss 4.637
# Ep 7 (Step 004025): Train loss 2.595, Val loss 4.621
# Ep 7 (Step 004030): Train loss 2.614, Val loss 4.640
# Ep 7 (Step 004035): Train loss 2.552, Val loss 4.637
# Ep 7 (Step 004040): Train loss 3.021, Val loss 4.649
# Ep 7 (Step 004045): Train loss 2.548, Val loss 4.641
# Ep 7 (Step 004050): Train loss 2.497, Val loss 4.655
# Ep 7 (Step 004055): Train loss 2.600, Val loss 4.650
# Ep 7 (Step 004060): Train loss 2.822, Val loss 4.634
# Ep 7 (Step 004065): Train loss 2.768, Val loss 4.634
# Ep 7 (Step 004070): Train loss 2.548, Val loss 4.641
# Ep 7 (Step 004075): Train loss 2.573, Val loss 4.657
# Ep 7 (Step 004080): Train loss 2.869, Val loss 4.655
# Ep 7 (Step 004085): Train loss 2.898, Val loss 4.670
# Ep 7 (Step 004090): Train loss 2.618, Val loss 4.660
# Ep 7 (Step 004095): Train loss 2.489, Val loss 4.672
# Ep 7 (Step 004100): Train loss 2.814, Val loss 4.684
# Ep 7 (Step 004105): Train loss 2.770, Val loss 4.665
# Ep 7 (Step 004110): Train loss 2.690, Val loss 4.654
# Ep 7 (Step 004115): Train loss 2.667, Val loss 4.666
# Ep 7 (Step 004120): Train loss 2.579, Val loss 4.663
# First Citizen: Ay, sir, sir, sir, sir, sir, And I am too, sir, And I am too much for't.  Second Servingman: I am too.  Third Servingman: I am
# Ep 8 (Step 004125): Train loss 2.776, Val loss 4.657
# Ep 8 (Step 004130): Train loss 2.627, Val loss 4.664
# Ep 8 (Step 004135): Train loss 2.720, Val loss 4.687
# Ep 8 (Step 004140): Train loss 2.547, Val loss 4.714
# Ep 8 (Step 004145): Train loss 2.672, Val loss 4.726
# Ep 8 (Step 004150): Train loss 2.918, Val loss 4.725
# Ep 8 (Step 004155): Train loss 2.614, Val loss 4.716
# Ep 8 (Step 004160): Train loss 2.832, Val loss 4.682
# Ep 8 (Step 004165): Train loss 2.492, Val loss 4.680
# Ep 8 (Step 004170): Train loss 2.639, Val loss 4.707
# Ep 8 (Step 004175): Train loss 2.537, Val loss 4.733
# Ep 8 (Step 004180): Train loss 2.323, Val loss 4.747
# Ep 8 (Step 004185): Train loss 2.441, Val loss 4.759
# Ep 8 (Step 004190): Train loss 2.484, Val loss 4.771
# Ep 8 (Step 004195): Train loss 2.612, Val loss 4.760
# Ep 8 (Step 004200): Train loss 2.701, Val loss 4.746
# Ep 8 (Step 004205): Train loss 2.553, Val loss 4.732
# Ep 8 (Step 004210): Train loss 2.459, Val loss 4.727
# Ep 8 (Step 004215): Train loss 2.315, Val loss 4.764
# Ep 8 (Step 004220): Train loss 2.577, Val loss 4.794
# Ep 8 (Step 004225): Train loss 2.534, Val loss 4.755
# Ep 10 (Step 005675): Train loss 1.560, Val loss 5.075
# Ep 10 (Step 005680): Train loss 1.502, Val loss 5.099
# Ep 10 (Step 005685): Train loss 1.752, Val loss 5.124
# Ep 10 (Step 005690): Train loss 1.622, Val loss 5.166
# Ep 10 (Step 005695): Train loss 1.806, Val loss 5.150
# Ep 10 (Step 005700): Train loss 1.560, Val loss 5.150
# Ep 10 (Step 005705): Train loss 1.404, Val loss 5.157
# Ep 10 (Step 005710): Train loss 1.682, Val loss 5.166
# Ep 10 (Step 005715): Train loss 1.578, Val loss 5.157
# Ep 10 (Step 005720): Train loss 1.450, Val loss 5.166
# Ep 10 (Step 005725): Train loss 1.651, Val loss 5.178
# Ep 10 (Step 005730): Train loss 1.539, Val loss 5.180
# Ep 10 (Step 005735): Train loss 1.655, Val loss 5.151
# Ep 10 (Step 005740): Train loss 1.619, Val loss 5.141
# Ep 10 (Step 005745): Train loss 1.372, Val loss 5.147
# Ep 10 (Step 005750): Train loss 1.516, Val loss 5.157
# Ep 10 (Step 005755): Train loss 1.721, Val loss 5.152
# Ep 10 (Step 005760): Train loss 1.484, Val loss 5.160
# Ep 10 (Step 005765): Train loss 1.492, Val loss 5.177
# Ep 10 (Step 005770): Train loss 1.753, Val loss 5.185
# Ep 10 (Step 005775): Train loss 1.564, Val loss 5.180
# Ep 10 (Step 005780): Train loss 1.445, Val loss 5.176
# Ep 10 (Step 005785): Train loss 1.674, Val loss 5.191
# Ep 10 (Step 005790): Train loss 1.435, Val loss 5.198
# Ep 10 (Step 005795): Train loss 1.641, Val loss 5.169
# Ep 10 (Step 005800): Train loss 1.551, Val loss 5.165
# Ep 10 (Step 005805): Train loss 1.554, Val loss 5.164
# Ep 10 (Step 005810): Train loss 1.523, Val loss 5.173
# Ep 10 (Step 005815): Train loss 1.649, Val loss 5.161
# Ep 10 (Step 005820): Train loss 1.606, Val loss 5.154
# Ep 10 (Step 005825): Train loss 1.524, Val loss 5.153
# Ep 10 (Step 005830): Train loss 1.483, Val loss 5.145
# Ep 10 (Step 005835): Train loss 1.424, Val loss 5.132
# Ep 10 (Step 005840): Train loss 1.436, Val loss 5.113
# Ep 10 (Step 005845): Train loss 1.441, Val loss 5.120
# Ep 10 (Step 005850): Train loss 1.501, Val loss 5.149
# Ep 10 (Step 005855): Train loss 1.488, Val loss 5.174
# Ep 10 (Step 005860): Train loss 1.494, Val loss 5.170
# Ep 10 (Step 005865): Train loss 1.376, Val loss 5.159
# Ep 10 (Step 005870): Train loss 1.440, Val loss 5.138
# Ep 10 (Step 005875): Train loss 1.446, Val loss 5.132
# Ep 10 (Step 005880): Train loss 1.340, Val loss 5.139
# Ep 10 (Step 005885): Train loss 1.463, Val loss 5.128
# First Citizen: What's the king is deposed?  CORIOLANUS: Ay, I pray you, sir, sir, Let me tell me of this of the city; and CORIOLANUS: Ay

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator


def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots(figsize=(5, 3))

    # Plot training and validation loss against epochs
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label="Validation loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))  # only show integer labels on x-axis

    # Create a second x-axis for tokens seen
    ax2 = ax1.twiny()  # Create a second x-axis that shares the same y-axis
    ax2.plot(tokens_seen, train_losses, alpha=0)  # Invisible plot for aligning ticks
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout()  # Adjust layout to make room
    plt.savefig("loss-plot.pdf")
    plt.show()

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)

# %% [markdown]
# ### Model Evaluation

# %%
start_context = "Hello, how are you?"

generate_and_print_sample(
    model, tokenizer, device, start_context, max_new_tokens=1000
)
# Out:
# Hello, how are you?  DUKE VINCENTIO: I will not be so.  DUKE VINCENTIO: I will not be so.  DUKE VINCENTIO: I will not be made no offence, that's images.  DUKE VINCENTIO: It shall be prepared.  DUKE VINCENTIO: Not that is sick my lord, As cause will.  DUKE VINCENTIO: It is the doth not so.  DUKE VINCENTIO: I will not be satisfied.  DUKE VINCENTIO: Not yon tuft of Lord Angelo, And so I will not be so.  DUKE VINCENTIO: I will not be hanged.  DUKE VINCENTIO: I will not do you will not be, It is my troth, I know not to me; and I do not say.  DUKE VINCENTIO: It is not yet to qualify the duke.  DUKE VINCENTIO: I'll make thee hence: I will you hence; and let me say, Lord Angelo comesCALUS: I am the friar, As I will not hear me well.  DUKE VINCENTIO: I will you hence: I'll send you: I am the friar, Lord Angelo comesCALUS: I will you hence.  DUKE VINCENTIO: I'll send you: I will not hear me.  DUKE VINCENTIO: I'll tell you: I am the friar, friar, and here's the friar, and the friar, and the friar, As well allied haste.  DUKE VINCENTIO: I thank you: I will not hear me well.  DUKE VINCENTIO: I will you hence.  DUKE VINCENTIO: I thank you: I will not hear me well met.  DUKE VINCENTIO: I thank you: I thank you: I'll tell you: I thank you: pray you, and the man that you will not hear me.  DUKE VINCENTIO: I thank you: I thank you: I thank you: I thank you: I thank you: I thank you: I thank you: I'll tell you: I thank you: pray you, friar, and the deputy will not take heed's ghost.  DUKE VINCENTIO: I'll send you: I thank you: I thank you: I thank you: I'll tell you: I thank you: I will not hear me.  DUKE VINCENTIO: I thank you: I will not hear me.  DUKE VINCENTIO: I will not take heed you are well met.  DUKE VINCENTIO: I will not speak.  DUKE VINCENTIO: I will not I will not speak.  DUKE VINCENTIO: I will not speak.  DUKE VINCENTIO: I will not bring me well.  DUKE VINCENTIO: I am going.  DUKE VINCENTIO: I will not take heed you will not hear me well.  DUKE VINCENTIO: I will not hear me.  DUKE VINCENTIO: I will not speak.  DUKE VINCENTIO: I will not take heed's a little better will not hear me well.  DUKE VINCENTIO: I will not hear me.  DUKE VINCENTIO: I will not hear me.  Provost: I will not take heed's the prison!  DUKE VINCENTIO: I will not hear me, friar, friar, friar, friar, friar, friar, and the man that you will not hear me.  DUKE VINCENTIO: I will not hear me, and the man that's a special man.  DUKE VINCENTIO: I will not hear me.  DUKE VINCENTIO: I will not hear me.  D
