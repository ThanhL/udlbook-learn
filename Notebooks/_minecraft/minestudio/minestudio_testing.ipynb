# %%
from minestudio.simulator import MinecraftSim
from minestudio.simulator.callbacks import RecordCallback
from minestudio.models import VPTPolicy

policy = VPTPolicy.from_pretrained("CraftJarvis/MineStudio_VPT.rl_from_early_game_2x").to("cuda")
policy.eval()

env = MinecraftSim(
    obs_size=(128, 128), 
    callbacks=[RecordCallback(record_path="./output", fps=30, frame_type="pov")]
)
memory = None
obs, info = env.reset()
for i in range(1200):
    action, memory = policy.get_action(obs, memory, input_shape='*')
    obs, reward, terminated, truncated, info = env.step(action)
env.close()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/traitlets/config/application.py", line 1082, in launch_instance
#     app.start()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 807, in start
#     self.io_loop.start()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#     await result
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#     reply_content = await reply_content
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 460, in do_execute
#     res = shell.run_cell(
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 665, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3170, in run_cell
#     result = self._run_cell(
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3225, in _run_cell
#     result = runner(coro)
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3447, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3688, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3748, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2732300/774087606.py", line 1, in <module>
#     from minestudio.simulator import MinecraftSim
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/minestudio/simulator/__init__.py", line 7, in <module>
#     from minestudio.simulator.entry import MinecraftSim
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/minestudio/simulator/entry.py", line 9, in <module>
#     import cv2
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/site-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/home/ein/miniconda3/envs/deepl/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from minestudio.simulator import MinecraftSim
#       2 from minestudio.simulator.callbacks import RecordCallback
#       3 from minestudio.models import VPTPolicy
#       4
#
# File ~/miniconda3/envs/deepl/lib/python3.11/site-packages/minestudio/simulator/__init__.py:7
#       1 '''
#       2 Date: 2024-11-11 05:09:07
#       3 LastEditors: muzhancun muzhancun@stu.pku.edu.cn
#       4 LastEditTime: 2024-11-15 15:00:02
#       5 FilePath: /Minestudio/minestudio/simulator/__init__.py
#       6 '''
# ----> 7 from minestudio.simulator.entry import MinecraftSim
#
# File ~/miniconda3/envs/deepl/lib/python3.11/site-packages/minestudio/simulator/entry.py:9
#       1 '''
#       2 Date: 2024-11-11 05:20:17
#       3 LastEditors: muzhancun muzhancun@stu.pku.edu.cn
#       4 LastEditTime: 2025-05-26 22:10:06
#       5 FilePath: /MineStudio/minestudio/simulator/entry.py
#       6 '''
#       8 import os
# ----> 9 import cv2
#      10 import argparse
#      11 import numpy as np
#
# File ~/miniconda3/envs/deepl/lib/python3.11/site-packages/cv2/__init__.py:181
#     176             if DEBUG: print("Extra Python code for", submodule, "is loaded")
#     178     if DEBUG: print('OpenCV loader: DONE')
# --> 181 bootstrap()
#
# File ~/miniconda3/envs/deepl/lib/python3.11/site-packages/cv2/__init__.py:153, in bootstrap()
#     149 if DEBUG: print("Relink everything from native cv2 module to cv2 package")
#     151 py_module = sys.modules.pop("cv2")
# --> 153 native_module = importlib.import_module("cv2")
#     155 sys.modules["cv2"] = py_module
#     156 setattr(py_module, "_native", native_module)
#
# File ~/miniconda3/envs/deepl/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# ImportError: numpy.core.multiarray failed to import

# %%
import torch
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    # Use PyTorch 2.9 or newer for stable mps results
    major, minor = map(int, torch.__version__.split(".")[:2])
    if (major, minor) >= (2, 9):
        device = torch.device("mps")
    else:
        device = torch.device("cpu")
else:
    device = torch.device("cpu")


print(f"Using {device} device.")
# Out:
# Using cuda device.
